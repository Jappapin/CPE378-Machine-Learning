# %% [markdown]
# # Lab4 Introduction to Reinforcement Learning
#
# ## Lab Instruction
#
# This lab, we will implement an Q-learning agent that will solve the GridWorld problem. The objective of your agent is to maximize the reward by find the shortest path to the exit without stepping on a bomb or a cliff. The result will be compare with the randomly move agent.
#
# ### Reinforcement Learning
#
# The reinforcement learning components:</br>
# <img src='https://github.com/thanatlap/CPE_CodeInAI_Course_2018/blob/master/9_RL/img/rl.png?raw=1' width=500>
#
# - Reinforcement Learning Blog Post (Thai): <a href="https://medium.com/asquarelab/ep-1-reinforcement-learning-%E0%B9%80%E0%B8%9A%E0%B8%B7%E0%B9%89%E0%B8%AD%E0%B8%87%E0%B8%95%E0%B9%89%E0%B8%99-acfa9d42394c"> Thammasorn, A-Square</a></br>
# - Reinforcement Learning Blog Post (Eng): <a href="http://adventuresinmachinelearning.com/reinforcement-learning-tutorial-python-keras/"> Adventures in Machine Learning</a>
#
# ### Temporal-Different Learning
# **Temporal-difference (TD) learning** is a combination of **Monte Carlo** ideas and **dynamic programming (DP)** ideas.</br>
# Like Monte Carlo methods, TD methods **can learn directly from raw experience without a model of the environment’s dynamics**.</br>
# Like DP, TD methods update estimates based in part on other learned estimates, **without waiting for a final outcome** (they bootstrap).</br>
# The relationship between TD, DP, and Monte Carlo methods is a recurring theme in the theory of reinforcement learning

# %%
# Setup 
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
import env as env

# %% [markdown]
# ### Environment - Cliff Gridworld
#
# The environment is a Cliff Gridworld, illustrated as follows: </br>
#
# <img src='https://github.com/thanatlap/CPE_CodeInAI_Course_2018/blob/master/9_RL/img/grid.png?raw=1' width=500></br>
#
# The world is a 10x10 grid where the exit is at bottom right corner. The bomb is randomly generated around the exit.</br>
# The agent is randomly start around the top left corner section. </br>
# Each step count as -1. In other word, the more step your agent take, the more penalty you have.</br>
# If your agent move against the corner, your agent will move. If your agent step to the cliff, the penalty is -20, same as stepping into a bomb which get -10 penalty.</br>
# If your agent reach to the exit, you will recieve 20 reward.</br>
#
# The episode is end when your agent found a way out and get a reward or step on a bomb and get the penalty point.</br>
# Your agent is at the starting point when the new episode begin.
#
# ```env.World```</br>
# >**Properties**
# - height: The height of a grid world
# - width: The width of a grid world
# - current_location: current location of your agent.
# - actions: a list of an available actions (up,down,left,right)</br>
#
# >**Methods**
# - ```available_actions()``` Get a set of available actions
# - ```move_agent(action)``` Move an agent to the given direction and return a reward of that action.
# - ```reset()``` Reset the state of the environment to the starting point.
# - ```end_state()``` Get the end state. Return True if the state is end. False, otherwise.
# - ```render()``` Show the current terran of the grid world

# %%
# Initialize environment
env = env.World()

# %%
env.available_actions()
# Out:
# ['up', 'down', 'left', 'right']

# %% [markdown]
# ### Define Random Agent
#
# Define an agent that walk randomly.

# %%
# Define Random Agent Object
# Random policy
class DumbAgent():
    def action(self, available_actions):
        return np.random.choice(available_actions)

# %%
# Test your code
agent = DumbAgent()
agent.action([1,2,3,4])
# Out:
# 2

# %% [markdown]
# ###  Define a Q-Agent
#
# Define an agent that used q-learning using the following pseudocode: </br>
# <img src='https://github.com/thanatlap/CPE_CodeInAI_Course_2018/blob/master/9_RL/img/q_learning.png?raw=1'>
#
# - S is a state of the environment
# - S' is a next state
# - A is a action choosen by the agent
# - A' is a next action
# - epsilon, alpha, gamma are the parameter for the agent

# %%
# Q-learning agent

class Q_Agent():
    
    def __init__(self, environment, alpha, gamma, epsilon):
        self.environment = environment
        
        # initial Q-table
        self.q_table = dict()
        for x in range(environment.height):
            for y in range(environment.width):
                self.q_table[(x,y)] = {'up':0,'down':0,'left':0,'right':0}
                
        self.alpha = alpha
        self.gamma = gamma
        self.epsilon = epsilon
        
        
    def action(self, available_actions):
        #
        # Code here
        #
        # if random number less than epsilon
        if np.random.uniform(0,1) < self.epsilon:
            # Exploration
            return np.random.choice(available_actions)
        else:
            # Exploitation go to the best way the agent knows
            S = self.q_table[self.environment.current_location]
            max_value = max(S.values())
            
            # random if you have multiple max value (many possibilities for max value)
            return np.random.choice([key for key, value in S.items() if value == max_value])

        
    # update the Q-table        
    def update(self, current_state, reward, next_state, actions):
        #
        # Code here
        #
        S_prime = self.q_table[next_state]
        max_value_S_prime = max(S_prime.values())
        current_Q_value = self.q_table[current_state][actions]
        
        # From the equation in pseudocode
        self.q_table[current_state][actions] = current_Q_value + self.alpha * (reward + self.gamma*max_value_S_prime - current_Q_value)

# %% [markdown]
# ###  Deploy Your Agent
#
# Create a function to run your agent in an environment. Your agent will run n trails, each trails has a maximum of m max_steps_per_episode.</br>
# For the Q-agent, you have to update Q-value for your agent using following code: </br>
# ```python
# if learn:
#     agent.update( ... )
# ```
#
# The function must record the total reward in each trials and return when the function end.
# ```python
# total_reward = run(env, agent, trials, max_steps_per_episode, learn=False)
# ```

# %%
# max_steps_per_episode = maximum step per round if agent reach the max steps the round will end

def run(env, agent, trials, max_steps_per_episode, learn=False):
    
    total_reward = []
    for trial in range(trials):
        
        sum_reward = 0
        step = 0
        game_over = False
        while step < max_steps_per_episode and not game_over:
            
            # Code here
            # Sent the action to environment and get the next state 
            # and reward
            current_state = env.current_location
            action = agent.action(env.actions)
            reward = env.move_agent(action)
            next_state = env.current_location
            
            # if learn = true Q-table will be updated
            if learn:
                agent.update(current_state, reward, next_state, action)
            
            sum_reward += reward
            step += 1
            
            if env.end_state():
                
                # reset the grid world environment
                env.reset()
                game_over = True
        
        total_reward.append(sum_reward)
    
    return total_reward

# %%
# Plot cumulative reward for each round
def plot_total_reward(total_reward):
    plt.plot(total_reward)
    plt.title('The Sum of Reward During Each Episode')
    plt.xlabel('Episode')
    plt.ylabel('Cumulative Reward')

# %% [markdown]
# ### Run a Dump Agent

# %%
## Run the Random agent
env.reset()
agent = DumbAgent()
total_reward = run(env, agent, trials=500, max_steps_per_episode=1000, learn=False) # no update Q-table

# %%
## Plot reward
plot_total_reward(total_reward)
# randomness
# no policies to guide for the right direction (to get the maximum Q*)

# %% [markdown]
# ### Run an Q-Agent

# %%
## Run the Q agent
env.reset()
agent = Q_Agent(env, alpha=0.01, gamma=1, epsilon=0.05)
total_reward = run(env, agent, trials=500, max_steps_per_episode=1000, learn=True) # update Q-table using as policies

# %%
## Plot reward
plot_total_reward(total_reward)
# the cumulative reward gets better every round (less negative)

# %% [markdown]
# ### change the parameter

# %% [markdown]
# alpha

# %%
## Run the Q agent change alpha
# greater alpha -> reach Q* quicker
env.reset()
agent = Q_Agent(env, alpha=0.05, gamma=1, epsilon=0.05)
total_reward = run(env, agent, trials=500, max_steps_per_episode=1000, learn=True)
plot_total_reward(total_reward)

# %%
## Run the Q agent change alpha
# smaller alpha -> reach Q* slower
env.reset()
agent = Q_Agent(env, alpha=0.005, gamma=1, epsilon=0.05)
total_reward = run(env, agent, trials=500, max_steps_per_episode=1000, learn=True)
plot_total_reward(total_reward)

# %%
## Run the Q agent change alpha
# smaller alpha -> reach Q* slower
# add more trials to see the change of Q
env.reset()
agent = Q_Agent(env, alpha=0.005, gamma=1, epsilon=0.05)
total_reward = run(env, agent, trials=2000, max_steps_per_episode=1000, learn=True)
plot_total_reward(total_reward)

# %% [markdown]
# gamma

# %%
## Run the Q agent change gamma
# greater gamma -> the action agent chooses in the future is more important -> reach the Q* fast
env.reset()
agent = Q_Agent(env, alpha=0.01, gamma=2, epsilon=0.05)
total_reward = run(env, agent, trials=500, max_steps_per_episode=1000, learn=True)
plot_total_reward(total_reward)

# %%
## Run the Q agent change gamma
# smaller gamma -> the action agent chooses in the future is less important -> the Q barely changes
env.reset()
agent = Q_Agent(env, alpha=0.01, gamma=0.1, epsilon=0.05)
total_reward = run(env, agent, trials=500, max_steps_per_episode=1000, learn=True)
plot_total_reward(total_reward)

# %%
## Run the Q agent change gamma
# smaller gamma -> the action agent chooses in the future is less important -> the Q barely changes
# add more trials to see the change of Q
env.reset()
agent = Q_Agent(env, alpha=0.01, gamma=0.1, epsilon=0.05)
total_reward = run(env, agent, trials=2000, max_steps_per_episode=1000, learn=True)
plot_total_reward(total_reward)

# %% [markdown]
# epsilon

# %%
## Run the Q agent change epsilon
# greater epsilon -> more chance for agent to explore the new way -> may need more round to train for reaching Q*
env.reset()
agent = Q_Agent(env, alpha=0.01, gamma=1, epsilon=0.9)
total_reward = run(env, agent, trials=500, max_steps_per_episode=1000, learn=True)
plot_total_reward(total_reward)

# %%
## Run the Q agent change epsilon
# greater epsilon -> more chance for agent to explore the new way -> may need more round (and less epsilon) to train for reaching Q*
# add more trials to see the change of Q
env.reset()
agent = Q_Agent(env, alpha=0.01, gamma=1, epsilon=0.9)
total_reward = run(env, agent, trials=5000, max_steps_per_episode=1000, learn=True)
plot_total_reward(total_reward)

# %%
## Run the Q agent change epsilon
# greater epsilon -> more chance for agent to explore the new way -> may need more round (and less epsilon) to train for reaching Q*
# add more trials to see the change of Q and change epsilon
env.reset()
agent = Q_Agent(env, alpha=0.01, gamma=1, epsilon=0.1)
total_reward = run(env, agent, trials=2000, max_steps_per_episode=1000, learn=True)
plot_total_reward(total_reward)

# %%
## Run the Q agent change epsilon
# smaller epsilon -> less chance for agent to explore the new way -> reach the Q* quicker
env.reset()
agent = Q_Agent(env, alpha=0.01, gamma=1, epsilon=0.00001)
total_reward = run(env, agent, trials=500, max_steps_per_episode=1000, learn=True)
plot_total_reward(total_reward)

# %% [markdown]
# ### Show Q-Table
#
# Show the agent's Q-table using to make a decision.

# %%
# show state-action pair with reward

def Viz_q_table(d, indent=0):
    for key, value in d.items():
        print('\t' * indent + str(key))
        if isinstance(value, dict):
            Viz_q_table(value, indent+1)
        else:
            print('\t' * (indent+1) + str(value))

# %%
Viz_q_table(agent.q_table)
# Out:
# (0, 0)
# 	up
# 		-3.649999999999966
# 	down
# 		-3.6447206007581805
# 	left
# 		-3.649999999999966
# 	right
# 		-3.653806042442337
# (0, 1)
# 	up
# 		-3.659999999999966
# 	down
# 		-3.66142001177202
# 	left
# 		-3.655976164502943
# 	right
# 		-3.6532099686299024
# (0, 2)
# 	up
# 		-3.5999999999999672
# 	down
# 		-3.598527691085237
# 	left
# 		-3.606248508982039
# 	right
# 		-3.5996099150697125
# (0, 3)
# 	up
# 		-3.5299999999999687
# 	down
# 		-3.528409970679574
# 	left
# 		-3.5317516106903386
# 	right
# 		-3.6767103130069754
# (0, 4)
# 	up
# 		-0.6000000000000001
# 	down
# 		-0.5991398923929654
# 	left
# 		-0.4525119354610676
# 	right
# 		-0.5980000000000001
# (0, 5)
# 	up
# 		-0.4
# 	down
# 		-0.5988569057921895
# 	left
# 		-0.401062163412068
# 	right
# 		-0.4
# (0, 6)
# 	up
# 		-0.4
# 	down
# 		-0.4
# 	left
# 		-0.4019955606112541
# 	right
# 		-0.4
# (0, 7)
# 	up
# 		-0.2
# 	down
# 		-0.2
# 	left
# 		-0.4
# 	right
# 		-0.20010000000000003
# (0, 8)
# 	up
# 		-0.2
# 	down
# 		-0.2
# 	left
# 		-0.2
# 	right
# 		-0.10884460023281001
# (0, 9)
# 	up
# 		-1.350000000000001
# 	down
# 		-1.3500246984460218
# 	left
# 		-1.36131212993115
# 	right
# 		-1.350000000000001
# (1, 0)
# 	up
# 		-3.6401297704587576
# 	down
# 		-3.6358544339241825
# 	left
# 		-3.6399999999999664
# 	right
# 		-3.6451928139821295
# (1, 1)
# 	up
# 		-3.706976287029088
# 	down
# 		-3.7082612758479927
# 	left
# 		-3.7019760412770903
# 	right
# 		-3.7012925023038283
# (1, 2)
# 	up
# 		-3.61794060770606
# 	down
# 		-3.6192204922971793
# 	left
# 		-3.62767909850881
# 	right
# 		-3.6214151166552266
# (1, 3)
# 	up
# 		-3.4674160088356523
# 	down
# 		-3.4606856397314583
# 	left
# 		-3.4590699507762914
# 	right
# 		-3.504781783920386
# (1, 4)
# 	up
# 		-0.4000859318913714
# 	down
# 		-0.40645308625224136
# 	left
# 		-0.4387134099426343
# 	right
# 		-0.5984621635819645
# (1, 5)
# 	up
# 		-0.4
# 	down
# 		-0.3610453646070427
# 	left
# 		-0.40087529590685944
# 	right
# 		-0.3993125859035209
# (1, 6)
# 	up
# 		-0.4
# 	down
# 		-0.20435619568514077
# 	left
# 		-0.40035207666781464
# 	right
# 		-0.39955595235134866
# (1, 7)
# 	up
# 		-0.2
# 	down
# 		-0.20564201444950578
# 	left
# 		-0.20010000000000003
# 	right
# 		-0.2
# (1, 8)
# 	up
# 		-0.2
# 	down
# 		-0.11138115382033915
# 	left
# 		-0.2
# 	right
# 		-0.12682561106505846
# (1, 9)
# 	up
# 		-1.3498026797052185
# 	down
# 		-1.3568051435607857
# 	left
# 		-1.3614384551184253
# 	right
# 		-1.350000000000001
# (2, 0)
# 	up
# 		-3.5714913573142986
# 	down
# 		-3.5707303938711847
# 	left
# 		-3.569999999999968
# 	right
# 		-3.5670727268583304
# (2, 1)
# 	up
# 		-3.6215609724518694
# 	down
# 		-3.6209425157824318
# 	left
# 		-3.6231231123893934
# 	right
# 		-3.6275038933721624
# (2, 2)
# 	up
# 		-3.516285774608188
# 	down
# 		-3.5226524520527214
# 	left
# 		-3.5235150001719293
# 	right
# 		-3.519106295603659
# (2, 3)
# 	up
# 		-3.232323186505053
# 	down
# 		-3.2314345130271027
# 	left
# 		-3.2317000799985354
# 	right
# 		-3.232859578569566
# (2, 4)
# 	up
# 		-2.9955457794184888
# 	down
# 		-2.8418993201632317
# 	left
# 		-2.8459199798298047
# 	right
# 		-2.838021813942804
# (2, 5)
# 	up
# 		-2.640719554428413
# 	down
# 		-2.4726526544134764
# 	left
# 		-2.476141855385993
# 	right
# 		-2.4764462593424588
# (2, 6)
# 	up
# 		-2.2830719083678184
# 	down
# 		-2.1172056034121924
# 	left
# 		-2.1094516800989007
# 	right
# 		-2.1088854378268023
# (2, 7)
# 	up
# 		-1.9191661665003514
# 	down
# 		-1.766389720344956
# 	left
# 		-1.7692587629322325
# 	right
# 		-1.7657168282461306
# (2, 8)
# 	up
# 		-1.5488060229541116
# 	down
# 		-1.4994336006984312
# 	left
# 		-1.5018067572115243
# 	right
# 		-1.4932724603963656
# (2, 9)
# 	up
# 		-1.346921565500593
# 	down
# 		-1.3474439590918443
# 	left
# 		-1.3527000566648115
# 	right
# 		-1.350000000000001
# (3, 0)
# 	up
# 		-3.4493906304824593
# 	down
# 		-3.446639481458598
# 	left
# 		-3.4499999999999704
# 	right
# 		-3.4514286918404866
# (3, 1)
# 	up
# 		-3.428627473614784
# 	down
# 		-3.4215473291238223
# 	left
# 		-3.4254712716182767
# 	right
# 		-3.430388526545972
# (3, 2)
# 	up
# 		-3.315461925720335
# 	down
# 		-3.316184767139892
# 	left
# 		-3.314941274746593
# 	right
# 		-3.3181164659456366
# (3, 3)
# 	up
# 		-3.089320496996812
# 	down
# 		-3.093695936141333
# 	left
# 		-3.0872219794426403
# 	right
# 		-3.091347746353125
# (3, 4)
# 	up
# 		-2.7637667988781187
# 	down
# 		-2.7728672411874586
# 	left
# 		-2.7726198343268997
# 	right
# 		-2.764907727574129
# (3, 5)
# 	up
# 		-2.4096694498369824
# 	down
# 		-2.406962384429932
# 	left
# 		-2.4041531758863752
# 	right
# 		-2.4091229093316446
# (3, 6)
# 	up
# 		-2.0445293161630342
# 	down
# 		-2.063857163563445
# 	left
# 		-2.045138352778137
# 	right
# 		-2.0417180914369326
# (3, 7)
# 	up
# 		-1.618332425576533
# 	down
# 		-1.6085460037569759
# 	left
# 		-1.6119655385161276
# 	right
# 		-1.6114411227520327
# (3, 8)
# 	up
# 		-1.3390555698919957
# 	down
# 		-1.3440718240322174
# 	left
# 		-1.347611577315471
# 	right
# 		-1.3389750736219757
# (3, 9)
# 	up
# 		-1.1821230668354932
# 	down
# 		-1.1782876559155082
# 	left
# 		-1.176529061867993
# 	right
# 		-1.1800000000000008
# (4, 0)
# 	up
# 		-3.3469307196220153
# 	down
# 		-3.337814159107231
# 	left
# 		-3.3399999999999728
# 	right
# 		-3.347142116823827
# (4, 1)
# 	up
# 		-3.3071716558868456
# 	down
# 		-3.3078902376760677
# 	left
# 		-3.3086261844890674
# 	right
# 		-3.3131522436357996
# (4, 2)
# 	up
# 		-3.21196089445542
# 	down
# 		-3.209401087820165
# 	left
# 		-3.219293362257064
# 	right
# 		-3.216813138102201
# (4, 3)
# 	up
# 		-3.0343655005505448
# 	down
# 		-3.0388627947706643
# 	left
# 		-3.0357721644102105
# 	right
# 		-3.0293689252776215
# (4, 4)
# 	up
# 		-2.7078191931220803
# 	down
# 		-2.814959296765364
# 	left
# 		-2.7040691245591075
# 	right
# 		-2.7054134158371337
# (4, 5)
# 	up
# 		-2.3056458049220465
# 	down
# 		-2.3008645596294044
# 	left
# 		-2.2968210152756416
# 	right
# 		-2.2995685419484473
# (4, 6)
# 	up
# 		0
# 	down
# 		0
# 	left
# 		0
# 	right
# 		0
# (4, 7)
# 	up
# 		-1.1749706002827973
# 	down
# 		-1.1745250413448522
# 	left
# 		-1.2247897700103203
# 	right
# 		-1.180554089999848
# (4, 8)
# 	up
# 		-1.0181974867325037
# 	down
# 		-1.0134509860541654
# 	left
# 		-1.0188402107014547
# 	right
# 		-1.012951935719928
# (4, 9)
# 	up
# 		-0.8143331876164754
# 	down
# 		-0.5823806017195791
# 	left
# 		-0.8109928655189589
# 	right
# 		-0.8100000000000005
# (5, 0)
# 	up
# 		-3.273065274606836
# 	down
# 		-3.270534874374424
# 	left
# 		-3.2699999999999743
# 	right
# 		-3.2710797841368286
# (5, 1)
# 	up
# 		-3.247563393644418
# 	down
# 		-3.241509133194516
# 	left
# 		-3.246128430801853
# 	right
# 		-3.2483405709382795
# (5, 2)
# 	up
# 		-3.1888874510713867
# 	down
# 		-3.192391423385627
# 	left
# 		-3.191710491093881
# 	right
# 		-3.1928110466940134
# (5, 3)
# 	up
# 		-3.1224434122252585
# 	down
# 		-3.127865451048342
# 	left
# 		-3.122225454246866
# 	right
# 		-3.1583877481988405
# (5, 4)
# 	up
# 		-0.31561864156514735
# 	down
# 		-0.39975336031667064
# 	left
# 		-0.2833108216735817
# 	right
# 		-0.2865072374493929
# (5, 5)
# 	up
# 		-1.8179490974151014
# 	down
# 		-1.8092525005746525
# 	left
# 		-1.9232792577340223
# 	right
# 		-1.8209306240276915
# (5, 6)
# 	up
# 		0
# 	down
# 		0
# 	left
# 		0
# 	right
# 		0
# (5, 7)
# 	up
# 		-0.8178734246901423
# 	down
# 		-0.805027180992656
# 	left
# 		-0.864827525163591
# 	right
# 		-0.8095238996076607
# (5, 8)
# 	up
# 		-0.6303756069892197
# 	down
# 		-0.6182311265153203
# 	left
# 		-0.6257005824073966
# 	right
# 		-0.4702109771309479
# (5, 9)
# 	up
# 		-0.4406342727936052
# 	down
# 		2.160484579761397
# 	left
# 		-0.43782977668036344
# 	right
# 		-0.4400000000000002
# (6, 0)
# 	up
# 		-3.228858645204061
# 	down
# 		-3.2332207093048897
# 	left
# 		-3.229999999999975
# 	right
# 		-3.226513188265143
# (6, 1)
# 	up
# 		-3.2129016194368774
# 	down
# 		-3.2194467143307497
# 	left
# 		-3.2103368699867048
# 	right
# 		-3.2124042055316884
# (6, 2)
# 	up
# 		-3.1858348661168994
# 	down
# 		-3.1862527347039755
# 	left
# 		-3.1881221053129614
# 	right
# 		-3.1792932470721773
# (6, 3)
# 	up
# 		-3.1492555560644715
# 	down
# 		-3.157974001042562
# 	left
# 		-3.1505800963041755
# 	right
# 		-3.154992048082897
# (6, 4)
# 	up
# 		-0.4004619192501583
# 	down
# 		-0.2
# 	left
# 		-0.23464936419617877
# 	right
# 		-0.21365945744793974
# (6, 5)
# 	up
# 		-1.2662378719103955
# 	down
# 		-1.2630210021327606
# 	left
# 		-1.36460436929698
# 	right
# 		-1.2686275030170493
# (6, 6)
# 	up
# 		-0.864827525163591
# 	down
# 		-0.8510062758305813
# 	left
# 		-0.8530065512267571
# 	right
# 		-0.8544325678817354
# (6, 7)
# 	up
# 		-0.5707621760315158
# 	down
# 		-0.5619288493713707
# 	left
# 		-0.5635581822049289
# 	right
# 		-0.5420510703193246
# (6, 8)
# 	up
# 		-0.3206935003077105
# 	down
# 		-0.31271913611939534
# 	left
# 		-0.3212179832541663
# 	right
# 		0.9343991455762345
# (6, 9)
# 	up
# 		-0.1677960292987717
# 	down
# 		8.048157403347785
# 	left
# 		-0.16291306010606238
# 	right
# 		-0.16
# (7, 0)
# 	up
# 		-3.207394416525943
# 	down
# 		-3.2150285703617674
# 	left
# 		-3.2099999999999755
# 	right
# 		-3.208838175650309
# (7, 1)
# 	up
# 		-3.2001580728519636
# 	down
# 		-3.204503731263424
# 	left
# 		-3.200108021854531
# 	right
# 		-3.2013945812443514
# (7, 2)
# 	up
# 		-3.183939795369443
# 	down
# 		-3.1853370998375796
# 	left
# 		-3.1836667326564623
# 	right
# 		-3.176088017571771
# (7, 3)
# 	up
# 		-3.1609890246174057
# 	down
# 		-3.162194045411951
# 	left
# 		-3.1618543582254226
# 	right
# 		-3.1529804863315043
# (7, 4)
# 	up
# 		-0.2
# 	down
# 		-0.2
# 	left
# 		-0.21026901953799454
# 	right
# 		-0.17697583667218578
# (7, 5)
# 	up
# 		-0.8790489228816537
# 	down
# 		-0.8815046624008235
# 	left
# 		-0.9836458992917981
# 	right
# 		-0.8825002869436022
# (7, 6)
# 	up
# 		-0.624673088466685
# 	down
# 		-0.6286509516139669
# 	left
# 		-0.6331060341393532
# 	right
# 		-0.6290998635062848
# (7, 7)
# 	up
# 		-0.32795838559412394
# 	down
# 		-0.32337655082526906
# 	left
# 		-0.326168757725824
# 	right
# 		-0.07917847425221272
# (7, 8)
# 	up
# 		-0.13389288263664378
# 	down
# 		-0.2
# 	left
# 		-0.14300341969036934
# 	right
# 		2.9010537239157608
# (7, 9)
# 	up
# 		-0.0201
# 	down
# 		14.469763335933711
# 	left
# 		-0.0201
# 	right
# 		-0.02
# (8, 0)
# 	up
# 		-3.197755849946578
# 	down
# 		-3.1981139502259848
# 	left
# 		-3.1999999999999758
# 	right
# 		-3.199895560170314
# (8, 1)
# 	up
# 		-3.1943364018031746
# 	down
# 		-3.18659116805073
# 	left
# 		-3.186757149975407
# 	right
# 		-3.1962450768400683
# (8, 2)
# 	up
# 		-3.179168388145216
# 	down
# 		-3.180221527018804
# 	left
# 		-3.178644773240427
# 	right
# 		-3.1723143577138924
# (8, 3)
# 	up
# 		-3.1601662602533227
# 	down
# 		-3.161699222979418
# 	left
# 		-3.1580286719543955
# 	right
# 		-3.1519201862595234
# (8, 4)
# 	up
# 		-0.2
# 	down
# 		-0.2
# 	left
# 		-0.1840959322952215
# 	right
# 		-0.14949065522250396
# (8, 5)
# 	up
# 		-0.5944823315961433
# 	down
# 		-0.5930714454395659
# 	left
# 		-0.5951463719393049
# 	right
# 		-0.5871791333697786
# (8, 6)
# 	up
# 		-0.3745216274141543
# 	down
# 		-0.34640117388079184
# 	left
# 		-0.3697747442403175
# 	right
# 		-0.36411986381898326
# (8, 7)
# 	up
# 		-0.16533053315384258
# 	down
# 		0.21561249413105363
# 	left
# 		-0.16488819574707922
# 	right
# 		-0.2
# (8, 8)
# 	up
# 		-0.01
# 	down
# 		-0.01
# 	left
# 		0
# 	right
# 		-0.01
# (8, 9)
# 	up
# 		0
# 	down
# 		18.800819706570696
# 	left
# 		0
# 	right
# 		0
# (9, 0)
# 	up
# 		-3.194028132810242
# 	down
# 		-3.189999999999976
# 	left
# 		-3.189999999999976
# 	right
# 		-3.184900005570923
# (9, 1)
# 	up
# 		-3.181815170185199
# 	down
# 		-3.179999999999976
# 	left
# 		-3.179554886766621
# 	right
# 		-3.1823677751731605
# (9, 2)
# 	up
# 		-3.1703944240835904
# 	down
# 		-3.1699999999999764
# 	left
# 		-3.172546363198782
# 	right
# 		-3.1735004075159203
# (9, 3)
# 	up
# 		-3.156857241251147
# 	down
# 		-3.1599999999999766
# 	left
# 		-3.152510731491119
# 	right
# 		-3.320829337251403
# (9, 4)
# 	up
# 		-0.2
# 	down
# 		-0.2
# 	left
# 		-0.1492893222943922
# 	right
# 		-0.153740450112125
# (9, 5)
# 	up
# 		-0.38877968923980305
# 	down
# 		-0.3900000000000002
# 	left
# 		-0.39839581
# 	right
# 		-0.3644329700958032
# (9, 6)
# 	up
# 		-0.164508605107389
# 	down
# 		-0.17
# 	left
# 		-0.1648443112663903
# 	right
# 		1.1484832355193386
# (9, 7)
# 	up
# 		-0.03010198
# 	down
# 		-0.03
# 	left
# 		-0.0302968
# 	right
# 		6.054066109009173
# (9, 8)
# 	up
# 		-0.2
# 	down
# 		0
# 	left
# 		0
# 	right
# 		14.01239217375337
# (9, 9)
# 	up
# 		0
# 	down
# 		0
# 	left
# 		0
# 	right
# 		0
